# %%
import sys
import torch
import numpy as np
import torch.nn as nn

sys.path.append('../model')
from NNsv2 import T_NNs, V_NNs
from DeLanv2 import Dynamic_System

sys.path.append('../utils')
from dataloaderv2 import MatDataLoader
from model_builder_v2 import KFoldTraining

# %%
'''
Preparing data...
'''
data_dir = "../data/"
data_length = 49998
data_set = MatDataLoader(data_length, data_dir)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
dynamic_system_instance = Dynamic_System(device)

builder = KFoldTraining(device = device, dataset = data_set, k_folds = 5, dynamic_system_instance = dynamic_system_instance)
builder.train(epochs = 80, batch_size = 64, learning_rate = 1e-4)
# Out:
# Fold 1/5
# Training size: 39996, Validation size: 9999
# --------------------------------------------------
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A42260>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A25BD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4AFA680>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4A0D3F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4A0EEF0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D54C54B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A426B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4AFA680>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5557910>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A426B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A40460>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41000>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDE830>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D44CC940>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41BD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D5556FB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D2650>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D1A50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A5B010>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB790>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB790>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A5B010>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD8BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A5B010>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4D79660>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9CF0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB490>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9CF0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41BD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE3E80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB040>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9CF0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9CF0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE3E80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4680BB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A40460>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A40460>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDE320>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDE740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDE320>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDE320>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D1A50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41BD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9AE0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9AE0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDA740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE58A0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF3E20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF3E20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF3E20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9AE0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDA740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDD810>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDD810>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDD810>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDA740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1B10>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDA740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDD810>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6B90>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDEDA0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDE920>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6AD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDE920>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A40C10>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6B90>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDA740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41000>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDA740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDA740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6AD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41BD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D48B7160>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41BD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6FE0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59510>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF190>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDEEF0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDE920>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59180>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6B90>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7100>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59180>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF2E0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE70D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A5A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE70D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41BD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41BD0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41000>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7100>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE58A0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6B90>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE70D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE70D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D44CC940>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A5A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7430>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59510>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A5A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF1F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A5A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7100>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE70D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59180>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59510>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59510>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE74F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A274F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A274F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A274F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF610>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE75B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE74F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE74F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7100>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7100>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A274F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE5A20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A274F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59180>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF6D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF670>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59510>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDA740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9FC0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A27520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D18D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE58A0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D18D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59180>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF2230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A41000>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26F50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF2230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D3DDF8B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF2740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1B40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26F50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59180>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59180>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D1990>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D3DDF8B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D1990>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D1990>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D1990>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7070>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A27520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7070>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26F50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A27520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D3DDF8B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A27520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A274F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D44CC940>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D58D1990>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D696F280>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE78E0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6F80>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF2230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7880>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59180>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A59180>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D3DDF8B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7100>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF880>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A42680>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A42680>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A418D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF880>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7940>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE78E0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF880>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE1000>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7880>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D513EC20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE74F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE70D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7880>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF250>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE79D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7A60>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D3DDF8B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7A60>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE70D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE70D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7100>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF820>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDFC10>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A42680>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26F50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7880>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4CCEF50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4CCEF50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# ...
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB040>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB040>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDFD00>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D47EFBB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE73D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9B40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB040>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26260>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB400>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF2740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26F50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB040>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BD9B40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7100>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDC820>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26F50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A590F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE58A0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7100>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE58A0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE7520>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF8B0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDC820>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB400>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDB040>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF2230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF2230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF820>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF820>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58B50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF2230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDDBA0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE79D0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE74F0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A58CA0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26260>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BE6C20>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26260>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF2740>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4CCEF50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BF1240>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDFBB0>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF820>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDCB50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDED40>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF760>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6A26D70>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4CCEF50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4CCEF50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D694A230>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D6BDF820>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: <SoftplusBackward0 object at 0x000001F2D4CCEF50>
# dT_dThetaDot is None? False
# T_NN requires_grad: True
# T_NN grad_fn: None
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       2 dynamic_system_instance = Dynamic_System(device)
#       4 builder = KFoldTraining(device = device, dataset = data_set, k_folds = 5, dynamic_system_instance = dynamic_system_instance)
# ----> 5 builder.train(epochs = 80, batch_size = 64, learning_rate = 1e-4)
#
# File c:\Users\FPTSHOP\Desktop\Project\2. DeLan model\run\../utils\model_builder_v2.py:116, in KFoldTraining.train(self, epochs, batch_size, learning_rate)
#     113 for epoch in range(epochs):
#     115     train_loss = self.__train_epoch(train_loader, dynamic_system, optimizer)
# --> 116     val_loss = self.__val_epoch(val_loader, dynamic_system, optimizer)
#     118     print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}")
#     119     print(f"f_v1: {dynamic_system.f_v1.item()}, f_v2: {dynamic_system.f_v2.item()}, f_v3: {dynamic_system.f_v3.item()}")
#
# File c:\Users\FPTSHOP\Desktop\Project\2. DeLan model\run\../utils\model_builder_v2.py:73, in KFoldTraining.__val_epoch(self, val_loader, dynamic_system, optimizer)
#      70 tau = batch['tau'].squeeze().float().to(self.device)
#      71 t = batch['t'].float()
# ---> 73 tau_pred = dynamic_system(q, q_dot, s, s_dot, t)
#      74 loss = self.criterion(tau_pred, tau)
#      75 val_loss += loss.item()
#
# File c:\Users\FPTSHOP\anaconda3\envs\DemoPublicationEnv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\FPTSHOP\anaconda3\envs\DemoPublicationEnv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\FPTSHOP\Desktop\Project\2. DeLan model\run\../model\DeLanv2.py:256, in Dynamic_System.forward(self, q, q_dot, s, s_dot, t)
#     253 self.F_c = self.F_c.expand(batch_size, 3, 3)
#     255 #---Predict Torque---#
# --> 256 tau_pred = self.Auxiliary_Calculation(q, q_dot, s, s_dot, t) + self.F_v @ (q_dot.unsqueeze(-1)) - self.F_c @ torch.sign(q_dot.unsqueeze(-1))
#     257 return tau_pred.squeeze()
#
# File c:\Users\FPTSHOP\Desktop\Project\2. DeLan model\run\../model\DeLanv2.py:184, in Dynamic_System.Auxiliary_Calculation(self, q, q_dot, s, s_dot, t)
#     174 def Auxiliary_Calculation(
#     175     self,
#     176     q: torch.Tensor,
#    (...)
#     180     t: torch.Tensor
#     181     ) -> torch.Tensor:
#     183     z = s_dot[:, 2:3]
# --> 184     _, ddT_dtdThetaDot, ddT_dtdXDot, ddT_dtdYDot, ddT_dtdZDot = T_Derivative(self.T_NN, q_dot, s_dot, t, self.device)
#     185     _, dV_dTheta, dV_dZ = V_Derivative(self.V_NN, q, z, self.device)
#     187     #---Define K matrix---#
#
# File c:\Users\FPTSHOP\Desktop\Project\2. DeLan model\run\../model\DeLanv2.py:51, in T_Derivative(T_NNsInstance, theta_dot, s_dot, t, device)
#      48 print(f"T_NN requires_grad: {T_NN.requires_grad}")
#      49 print(f"T_NN grad_fn: {T_NN.grad_fn}")
# ---> 51 dT_dThetaDot = torch.autograd.grad(
#      52     outputs = T_NN, inputs = theta_dot,
#      53     grad_outputs=torch.ones_like(T_NN),
#      54     create_graph=True, retain_graph = True,
#      55     allow_unused=False
#      56 )[0]
#      58 print(f"dT_dThetaDot is None? {dT_dThetaDot is None}")
#      60 dT_dSDot = torch.autograd.grad(
#      61     outputs = T_NN, inputs = s_dot,
#      62     grad_outputs=torch.ones_like(T_NN),
#      63     create_graph=True, retain_graph = True,
#      64     allow_unused=False
#      65 )[0]
#
# File c:\Users\FPTSHOP\anaconda3\envs\DemoPublicationEnv\Lib\site-packages\torch\autograd\__init__.py:496, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     492     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     493         grad_outputs_
#     494     )
#     495 else:
# --> 496     result = _engine_run_backward(
#     497         outputs,
#     498         grad_outputs_,
#     499         retain_graph,
#     500         create_graph,
#     501         inputs,
#     502         allow_unused,
#     503         accumulate_grad=False,
#     504     )
#     505 if materialize_grads:
#     506     if any(
#     507         result[i] is None and not is_tensor_like(inputs[i])
#     508         for i in range(len(inputs))
#     509     ):
#
# File c:\Users\FPTSHOP\anaconda3\envs\DemoPublicationEnv\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# RuntimeError: One of the differentiated Tensors appears to not have been used in the graph. Set allow_unused=True if this is the desired behavior.
